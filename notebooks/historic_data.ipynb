# %%
import requests

# %%
def get_coin_full_name():
    url = "https://api.coincap.io/v2/assets"
    response = requests.get(url)
    coin_dict = {}
    if response.status_code == 200:
        data = response.json()
        assets = data.get('data', [])
        for asset in assets:
            coin_dict[asset['symbol']] = asset['name']
    return  coin_dict

coin_dict = get_coin_full_name()
l = ['ETH', 'BTC', 'LTC', 'XRP', 'JJJ', 'EOS', 'EOSBTC']

for i in l:
    if i in coin_dict.keys():
        if coin_dict[i] != i:
            print(coin_dict[i])

# 
# print(get_coin_full_name("ASTR"))
# Out:
# Ethereum
# Bitcoin
# Litecoin

# %%
def get_all_coins():
    url = "https://api.coingecko.com/api/v3/coins/list"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        coins_dict = {coin['symbol'].upper(): coin['name'] for coin in data}
        return coins_dict
    else:
        print("Failed to fetch data from CoinGecko API")
        return {}

import json

all_coins= get_all_coins()
print(all_coins)
all_coins = get_all_coins()
with open("coin_name_dict.json", "w") as f:
    json.dump(all_coins, f, indent=4)
# Out:
# {'ZOC': '01coin', 'ZCN': 'Zus', '0KN': '0 Knowledge Network', 'OME': 'O-MEE', 'VIX': 'Vixco', 'ZEROVM': '0VM', 'ZRX': '0x Protocol', '0X0': '0x0.ai: AI Smart Contract', '0X1': '0x1.tools: AI Multi-tool', '0XAISWAP': '0xAISwap', '0XANON': '0xAnon', '0XB': '0xBlack', 'COCO': 'Coco', '0XCON': '0xConnect', 'OXD': '0xDAO', 'CAFE': '0xDEFCAFE', 'ENGAGE': '0xEngage', '0XFREE': '0xFreelance', '0XF': '0xFriend', '0XG': '0xgambit', '0XGAS': '0xGasless', 'OXL': '0x Leverage', '0XLSD': '0xLSD', '0XMR': '0xMonero', 'NUDE': '0xNude', 'OXN': '0xNumber', '0XOS': '0xOS AI', '$0XS': '0xS', 'SCAN': 'ScanAI', '0XSPAI': '0xSnipeProAi', '0XT': '0xTools', 'VAULT': 'Vaulteum', '1000BONK': '1000BONK', '1000BTT': '1000BTT', '1000RATS': '1000RATS', '1000SATS': '1000SATS (Ordinals)', '1000SHIB': '1000SHIB', '1000TROLL': '1000TROLL', 'TSHP': '12Ships', '16DAO': '16DAO', '1ART': 'OneArt', '1EX': '1ex', 'WATER': 'WATER (BSC)', '1INCH': '1inch', 'YV1INCH': '1INCH yVault', '1LONG': '1LONG', '1MIL': '1MillionNFTs', '1MB': '1minBET', '1MT': '1Move Token', '1RT': '1Reward Token', 'SAFU': 'StaySAFU', '1SOL': '1Sol', '₿': '₿', '2024': '2024', 'PUMP': 'Pumpkin', '2049': '2049', '2080': '2080', '20WETH-80BAL': '20WETH-80BAL', '21M': '21Million', '28': '28', 'VCK': '28VCK', 'ARMS': '2ACoin', '2DAI': '2DAI.io', '2GCC': '2G Carbon Coin', 'MOON': 'Polywolf', '2OMB': '2omb', '2SHARES': '2SHARE', 'MEOW': 'ZERO', 'FIT': 'Fit', 'A3A': '3A', '3D3D': '3d3d', 'P3D': '3DPass', '3KM': '3 Kingdoms Multiverse', 'PACE': '3SPACE ART', '3WILD': '3WILD', 'BAKE': 'BakerySwap', '4096': '4096', '42': '42-coin', '4CHAN': '4Chan', '4DC': '4DCoin', '4DMAPS': '4D Twin Maps', '4INT': '4INT', '4JNET': '4JNET', 'NXTU': '4 Next Unicorn', '50CAL': '50cal', '50C': '50Cent', 'VGC': '5G-CASH', '5IRE': '5ire', '5MC': '5mc', '69420': '69420', '777': 'Jackpot', '888': 'Lucky8', 'MPH': 'Morpher', '8BIT': '8BITEARN', '8PAY': '8Pay', '90S': '90s Crypto Exchange', 'STZ': 'Suitizen', '9INCH': '9inch ETH', 'AA': 'Astarter', 'A4': 'A4 Finance', 'LENFI': 'Lenfi', 'AAG': 'AAG', 'ARDVRK': 'Aardvark [OLD]', 'VARK': 'Aardvark', 'ARMA': 'Aarma', 'AAVE': 'Aave', 'AAAVE': 'Aave v3 AAVE', 'AAMMBPTBALWETH': 'Aave AMM BptBALWETH', 'AAMMBPTWBTCWETH': 'Aave AMM BptWBTCWETH', 'AAMMDAI': 'Aave AMM DAI', 'AAMMUNIAAVEWETH': 'Aave AMM UniAAVEWETH', 'AAMMUNIBATWETH': 'Aave AMM UniBATWETH', 'AAMMUNICRVWETH': 'Aave AMM UniCRVWETH', 'AAMMUNIDAIUSDC': 'Aave AMM UniDAIUSDC', 'AAMMUNIDAIWETH': 'Aave AMM UniDAIWETH', 'AAMMUNILINKWETH': 'Aave AMM UniLINKWETH', 'AAMMUNIMKRWETH': 'Aave AMM UniMKRWETH', 'AAMMUNIRENWETH': 'Aave AMM UniRENWETH', 'AAMMUNISNXWETH': 'Aave AMM UniSNXWETH', 'AAMMUNIUNIWETH': 'Aave AMM UniUNIWETH', 'AAMMUNIUSDCWETH': 'Aave AMM UniUSDCWETH', 'AAMMUNIWBTCUSDC': 'Aave AMM UniWBTCUSDC', 'AAMMUNIWBTCWETH': 'Aave AMM UniWBTCWETH', 'AAMMUNIYFIWETH': 'Aave AMM UniYFIWETH', 'AAMMUSDC': 'Aave AMM USDC', 'AAMMUSDT': 'Aave AMM USDT', 'AAMMWBTC': 'Aave AMM WBTC', 'AAMMWETH': 'Aave AMM WETH', 'ABAL': 'Arch Balanced Portfolio', 'ABPT': 'Aave Balancer Pool Token', 'ABAT': 'Aave BAT v1', 'ABUSD': 'Aave BUSD v1', 'ACRV': 'Aave v3 CRV', 'ADAI': 'Aave v3 DAI', 'AENJ': 'Aave ENJ v1', 'AETH': 'Aave ETH v1', 'GHST': 'Aavegotchi', 'ALPHA': 'Alpha Shards', 'FOMO': 'FomoFi', 'FUD': 'Fud the Pug', 'KEK': 'Pepe Prophet', 'AGUSD': 'Angle USD', 'ASTETH': 'Aave Interest Bearing STETH', 'AKNC': 'Aave v3 KNC', 'ALINK': 'ALINK AI', 'AMANA': 'Aave MANA v1', 'AMKR': 'Aave v3 MKR', 'AMAAVE': 'Aave Polygon AAVE', 'AMDAI': 'Aave Polygon DAI', 'AMUSDC': 'Aave Polygon USDC', 'AMUSDT': 'Aave Polygon USDT', 'AMWBTC': 'Aave Polygon WBTC', 'AMWETH': 'Aave Polygon WETH', 'AMWMATIC': 'Aave Polygon WMATIC', 'ARAI': 'Aave RAI', 'AREN': 'Aave REN v1', 'ASNX': 'Aave v3 SNX', 'STKGHO': 'Aave stkGHO', 'ASUSD': 'Aave v3 sUSD', 'ATUSD': 'Aave TUSD v1', 'AUNI': 'Aave v3 UNI', 'AUSDC': 'SpaceShipX aUSDC', 'AUSDT': 'Aave v3 USDT', 'A1INCH': 'Aave v3 1INCH', 'AAGEUR': 'Aave v3 agEUR', 'AARB': 'Aave v3 ARB', 'ABTC.B': 'Aave v3 BTC.b', 'ACBETH': 'Aave v3 cbETH', 'ADPI': 'A ...

# %%
print(all_coins['ADA'])
# Out:
# Cardano

# %%
def get_all_coins():
    url = "https://api.coingecko.com/api/v3/coins/list"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        coins_dict = {}
        duplicates = {}
        for coin in data:
            symbol = coin['symbol'].upper()
            name = coin['name']
            if symbol in coins_dict:
                if symbol not in duplicates:
                    duplicates[symbol] = [coins_dict[symbol], name]
                else:
                    duplicates[symbol].append(name)
            else:
                coins_dict[symbol] = name
        if duplicates:
            print("Duplicates:")
            for symbol, names in duplicates.items():
                print(f"Symbol: {symbol}, Names: {', '.join(names)}")
        return coins_dict
    else:
        print("Failed to fetch data from CoinGecko API")
        return {}

all_coins = get_all_coins()
