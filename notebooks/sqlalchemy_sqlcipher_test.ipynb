# %%
from sqlalchemy import create_engine, Column, Integer, String, DateTime
from sqlalchemy.orm import declarative_base
from sqlalchemy.orm import sessionmaker
from datetime import datetime

# Define the base class for our ORM model
Base = declarative_base()


# Define the model class for the table
class ApiCredentials(Base):
    __tablename__ = 'api_credentials'

    id = Column(Integer, primary_key=True)
    name = Column(String, nullable=False)
    api_key = Column(String, nullable=False)
    secret_key = Column(String, nullable=True)
    created_at = Column(DateTime, default=datetime.utcnow, nullable=False)
    api_metadata = Column(String, nullable=True)  # This is the extra field

    def __repr__(self):
        return f"<ApiCredentials(name={self.name}, api_key={self.api_key}, secret_key={self.secret_key}, created_at={self.created_at}, api_metadata={self.api_metadata})>"


# Create the DB client class
class DBClient:
    def __init__(self, db_url: str, password: str):
        # Create an encrypted SQLAlchemy engine using SQLCipher
        self.engine = create_engine(f"sqlite+sqlcipher:///{db_url}?cipher=aes-256-cbc&key={password}")
        Base.metadata.create_all(self.engine)  # Create tables if they don't exist
        self.Session = sessionmaker(bind=self.engine)

    def insert(self, name: str, api_key: str, secret_key: str, api_metadata: str = None):
        """Insert a new record into the api_credentials table."""
        session = self.Session()
        new_record = ApiCredentials(
            name=name,
            api_key=api_key,
            secret_key=secret_key,
            api_metadata=api_metadata
        )
        session.add(new_record)
        session.commit()
        session.close()
        print(f"Inserted new record: {new_record}")

    def update(self, record_id: int, name: str = None, api_key: str = None, secret_key: str = None,
               api_metadata: str = None):
        """Update an existing record by ID."""
        session = self.Session()
        record = session.query(ApiCredentials).filter(ApiCredentials.id == record_id).first()

        if record:
            if name:
                record.name = name
            if api_key:
                record.api_key = api_key
            if secret_key:
                record.secret_key = secret_key
            if api_metadata is not None:  # If provided, update api_metadata
                record.api_metadata = api_metadata
            session.commit()
            print(f"Updated record: {record}")
        else:
            print(f"No record found with ID {record_id}")

        session.close()

    def delete(self, record_id: int):
        """Delete a record by ID."""
        session = self.Session()
        record = session.query(ApiCredentials).filter(ApiCredentials.id == record_id).first()

        if record:
            session.delete(record)
            session.commit()
            print(f"Deleted record: {record}")
        else:
            print(f"No record found with ID {record_id}")

        session.close()

    def get_all(self):
        """Fetch all records from the api_credentials table."""
        session = self.Session()
        records = session.query(ApiCredentials).all()
        session.close()
        return records


# Example usage
if __name__ == "__main__":
    # DB setup
    db_url = 'encrypted_db.db'  # Path to your encrypted database
    db_password = 'your_encryption_password'  # The encryption key for the database
    client = DBClient(db_url, db_password)

    # Insert a new record
    client.insert(name="MyApp", api_key="my_api_key", secret_key="my_secret_key", api_metadata="Some extra data")

    # Update a record by ID (example with id 1)
    client.update(record_id=1, name="UpdatedApp", api_key="new_api_key", api_metadata="Updated extra data")

    # Fetch all records
    records = client.get_all()
    for record in records:
        print(record)

    # Delete a record by ID (example with id 1)
    client.delete(record_id=1)
# Out:
# ---------------------------------------------------------------------------
# NoSuchModuleError                         Traceback (most recent call last)
# Cell In[4], line 96
#      94 db_url = 'encrypted_db.db'  # Path to your encrypted database
#      95 db_password = 'your_encryption_password'  # The encryption key for the database
# ---> 96 client = DBClient(db_url, db_password)
#      98 # Insert a new record
#      99 client.insert(name="MyApp", api_key="my_api_key", secret_key="my_secret_key", api_metadata="Some extra data")
#
# Cell In[4], line 29, in DBClient.__init__(self, db_url, password)
#      27 def __init__(self, db_url: str, password: str):
#      28     # Create an encrypted SQLAlchemy engine using SQLCipher
# ---> 29     self.engine = create_engine(f"sqlite+sqlcipher:///{db_url}?cipher=aes-256-cbc&key={password}")
#      30     Base.metadata.create_all(self.engine)  # Create tables if they don't exist
#      31     self.Session = sessionmaker(bind=self.engine)
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File ~/PycharmProjects/sibyl/.sibyl_venv/lib/python3.12/site-packages/sqlalchemy/util/deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# File ~/PycharmProjects/sibyl/.sibyl_venv/lib/python3.12/site-packages/sqlalchemy/engine/create.py:553, in create_engine(url, **kwargs)
#     549 u = _url.make_url(url)
#     551 u, plugins, kwargs = u._instantiate_plugins(kwargs)
# --> 553 entrypoint = u._get_entrypoint()
#     554 _is_async = kwargs.pop("_is_async", False)
#     555 if _is_async:
#
# File ~/PycharmProjects/sibyl/.sibyl_venv/lib/python3.12/site-packages/sqlalchemy/engine/url.py:772, in URL._get_entrypoint(self)
#     770 else:
#     771     name = self.drivername.replace("+", ".")
# --> 772 cls = registry.load(name)
#     773 # check for legacy dialects that
#     774 # would return a module with 'dialect' as the
#     775 # actual class
#     776 if (
#     777     hasattr(cls, "dialect")
#     778     and isinstance(cls.dialect, type)
#     779     and issubclass(cls.dialect, Dialect)
#     780 ):
#
# File ~/PycharmProjects/sibyl/.sibyl_venv/lib/python3.12/site-packages/sqlalchemy/util/langhelpers.py:375, in PluginLoader.load(self, name)
#     372         self.impls[name] = impl.load
#     373         return impl.load()
# --> 375 raise exc.NoSuchModuleError(
#     376     "Can't load plugin: %s:%s" % (self.group, name)
#     377 )
#
# NoSuchModuleError: Can't load plugin: sqlalchemy.dialects:sqlite.sqlcipher
